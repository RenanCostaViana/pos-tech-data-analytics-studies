# %% [markdown]
# # Desafio

# %% [markdown]
# * Realizar outras análises para o IDHM - 2021 e retirar outros insights.
# * Utilize a consulta por Estado e analisem a composição do indicador (Eduação, Longevidade, Renda)
# * Estudem sobre o indicador.
#
# Utilizem o site
# http://www.atlasbrasil.org.br/

# %% [markdown]
# 0 - 0,499 - Baixo Desenvolvimento Humano<br/>
# 0,5 - 0,799 - Médio Desenvolvimento Humano<br/>
# 0,8 - 1 - Alto Desenvolvimento Humano

# %% [markdown]
# ## Preparação

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_excel('IDH_2010.xls')

# %%
dados.head()
# Out:
#     ANO  Código da Unidade da Federação Nome da Unidade da Federação  \
# 0  2010                              11                     Rondônia
# 1  2010                              11                     Rondônia
# 2  2010                              11                     Rondônia
# 3  2010                              11                     Rondônia
# 4  2010                              11                     Rondônia
#
#    Código do Município              Município  Esperança de vida ao nascer  \
# 0               110001  ALTA FLORESTA D'OESTE                        70.75
# 1               110002              ARIQUEMES                        73.36
# 2               110003                 CABIXI                        70.39
# 3               110004                 CACOAL                        74.27
# 4               110005             CEREJEIRAS                        72.94
#
#    Taxa de fecundidade total  Mortalidade infantil  \
# ...

# %%
dados.tail()
# Out:
#        ANO  Código da Unidade da Federação Nome da Unidade da Federação  \
# 5559  2010                              52                        Goiás
# 5560  2010                              52                        Goiás
# 5561  2010                              52                        Goiás
# 5562  2010                              52                        Goiás
# 5563  2010                              53             Distrito Federal
#
#       Código do Município       Município  Esperança de vida ao nascer  \
# 5559               522200      VIANÓPOLIS                        74.10
# 5560               522205  VICENTINÓPOLIS                        73.25
# 5561               522220        VILA BOA                        74.07
# 5562               522230   VILA PROPÍCIO                        73.09
# 5563               530010        BRASÍLIA                        77.35
#
#       Taxa de fecundidade total  Mortalidade infantil  \
# ...

# %%
dados.columns
# Out:
# Index(['ANO', 'Código da Unidade da Federação', 'Nome da Unidade da Federação',
#        'Código do Município', 'Município', 'Esperança de vida ao nascer',
#        'Taxa de fecundidade total', 'Mortalidade infantil',
#        'Mortalidade até 5 anos de idade', 'Razão de dependência',
#        ...
#        'População de 15 a 17 anos.1', 'População de 18 anos ou mais.1',
#        'População total em domicílios particulares permanentes',
#        'População total em domicílios particulares permanentes, exceto com renda nula',
#        'Subíndice de escolaridade - IDHM Educação',
#        'Subíndice de frequência escolar - IDHM Educação', 'IDHM',
#        'IDHM Educação', 'IDHM Longevidade', 'IDHM Renda'],
#       dtype='object', length=237)

# %%
dados.shape
# Out:
# (5564, 237)

# %%
dados['ANO'].unique()
# Out:
# array([2010])

# %%
dados.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
dados.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Por Estado

# %%
idhm_estados = dados[['Nome da Unidade da Federação','IDHM','IDHM Educação','IDHM Longevidade','IDHM Renda']]

# %%
idhm_estados.head()
# Out:
#   Nome da Unidade da Federação   IDHM  IDHM Educação  IDHM Longevidade  \
# 0                     Rondônia  0.641          0.526             0.763
# 1                     Rondônia  0.702          0.600             0.806
# 2                     Rondônia  0.650          0.559             0.757
# 3                     Rondônia  0.718          0.620             0.821
# 4                     Rondônia  0.692          0.602             0.799
#
#    IDHM Renda
# 0       0.657
# 1       0.716
# 2       0.650
# 3       0.727
# 4       0.688

# %%
''' def grafico_estado (coluna):
  idhm_estados.groupby('Nome da Unidade da Federação')[coluna].mean().sort_values(ascending=False).plot(kind='bar')
  plt.title(f'{coluna} por Estado')
  plt.xlabel('Estado')
  plt.ylabel(f'{coluna}')
  plt.show() '''

# %%
idhm_estados_agrupado = idhm_estados.groupby('Nome da Unidade da Federação').mean().sort_values(by='IDHM',
    ascending=False)
idhm_estados_agrupado.head()
# Out:
#                                   IDHM  IDHM Educação  IDHM Longevidade  \
# Nome da Unidade da Federação
# Distrito Federal              0.824000       0.742000          0.873000
# São Paulo                     0.739527       0.676336          0.835992
# Santa Catarina                0.731648       0.636522          0.846966
# Rio Grande do Sul             0.713530       0.600714          0.840429
# Rio de Janeiro                0.708913       0.620902          0.816098
#
#                               IDHM Renda
# Nome da Unidade da Federação
# Distrito Federal                0.863000
# São Paulo                       0.716487
# Santa Catarina                  0.728038
# Rio Grande do Sul               0.722115
# Rio de Janeiro                  0.704565

# %%
plt.figure(figsize=(11, 6))

plt.scatter(idhm_estados_agrupado.index, idhm_estados_agrupado['IDHM'], label='IDHM')
plt.scatter(idhm_estados_agrupado.index, idhm_estados_agrupado['IDHM Educação'], label='IDHM Educação')
plt.scatter(idhm_estados_agrupado.index, idhm_estados_agrupado['IDHM Longevidade'], label='IDHM Longevidade')
plt.scatter(idhm_estados_agrupado.index, idhm_estados_agrupado['IDHM Renda'], label='IDHM Renda')

plt.title('IDHM e seus subtipos por Estado')
plt.legend(loc='lower left')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Por região

# %%
região = {'Acre':'Norte', 'Amapá':'Norte', 'Amazonas':'Norte', 'Pará':'Norte', 'Rondônia':'Norte',
          'Roraima':'Norte', 'Tocantins':'Norte', 'Maranhão':'Nordeste', 'Piauí':'Nordeste',
          'Ceará':'Nordeste', 'Rio Grande do Norte':'Nordeste', 'Paraíba':'Nordeste',
          'Pernambuco':'Nordeste', 'Alagoas':'Nordeste', 'Sergipe':'Nordeste', 'Bahia':'Nordeste',
          'Minas Gerais':'Sudeste', 'Espírito Santo':'Sudeste', 'Rio de Janeiro':'Sudeste',
          'São Paulo':'Sudeste', 'Paraná':'Sul', 'Santa Catarina':'Sul', 'Rio Grande do Sul':'Sul',
          'Mato Grosso do Sul':'Centro-Oeste', 'Mato Grosso':'Centro-Oeste',
          'Goiás':'Centro-Oeste', 'Distrito Federal':'Centro-Oeste'}

# %%
idhm_regiao = idhm_estados.copy()

# %%
idhm_regiao['Região'] = idhm_regiao['Nome da Unidade da Federação'].map(região)

# %%
idhm_regiao.head()
# Out:
#   Nome da Unidade da Federação   IDHM  IDHM Educação  IDHM Longevidade  \
# 0                     Rondônia  0.641          0.526             0.763
# 1                     Rondônia  0.702          0.600             0.806
# 2                     Rondônia  0.650          0.559             0.757
# 3                     Rondônia  0.718          0.620             0.821
# 4                     Rondônia  0.692          0.602             0.799
#
#    IDHM Renda Região
# 0       0.657  Norte
# 1       0.716  Norte
# 2       0.650  Norte
# 3       0.727  Norte
# 4       0.688  Norte

# %%
''' def grafico_regiao (coluna):
  idhm_regiao.groupby('Região')[coluna].mean().sort_values(ascending=False).plot(kind='bar')
  plt.title(f'{coluna} por Região')
  plt.xlabel('Região')
  plt.ylabel(f'{coluna}')
  plt.show() '''

# %%
idhm_regiao_agrupado = idhm_regiao.groupby('Região').mean(numeric_only=True).sort_values(by='IDHM', ascending=False)
idhm_regiao_agrupado
# Out:
#                   IDHM  IDHM Educação  IDHM Longevidade  IDHM Renda
# Região
# Sul           0.714113       0.613015          0.835332    0.713444
# Sudeste       0.698984       0.608189          0.828186    0.681157
# Centro-Oeste  0.689468       0.584142          0.822444    0.684489
# Norte         0.607951       0.490428          0.780381    0.592824
# Nordeste      0.590672       0.488406          0.754316    0.562270

# %%
plt.figure(figsize=(11, 6))

plt.scatter(idhm_regiao_agrupado.index, idhm_regiao_agrupado['IDHM'], label='IDHM')
plt.scatter(idhm_regiao_agrupado.index, idhm_regiao_agrupado['IDHM Educação'], label='IDHM Educação')
plt.scatter(idhm_regiao_agrupado.index, idhm_regiao_agrupado['IDHM Longevidade'], label='IDHM Longevidade')
plt.scatter(idhm_regiao_agrupado.index, idhm_regiao_agrupado['IDHM Renda'], label='IDHM Renda')

plt.title('IDHM e seus subtipos por Região')
plt.legend(loc='lower left')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Estados por região

# %%
''' def grafico_estado_regiao (coluna, regiao):
  idhm_regiao.query('Região == @regiao').groupby('Nome da Unidade da Federação')[coluna].mean().sort_values(ascending=False).plot(kind='bar')
  plt.title(f'{coluna} por estado ({regiao})')
  plt.xlabel('Estado')
  plt.ylabel(f'{coluna} ')
  plt.show() '''

# %%
def scatter_estado_regiao (regiao):
  regiao_agrupada = idhm_regiao.query('Região == @regiao').groupby('Nome da Unidade da Federação').mean(numeric_only=True).sort_values(by='IDHM', ascending=False)

  plt.figure(figsize=(11, 6))

  plt.scatter(regiao_agrupada.index, regiao_agrupada['IDHM'], label='IDHM')
  plt.scatter(regiao_agrupada.index, regiao_agrupada['IDHM Educação'], label='IDHM Educação')
  plt.scatter(regiao_agrupada.index, regiao_agrupada['IDHM Longevidade'], label='IDHM Longevidade')
  plt.scatter(regiao_agrupada.index, regiao_agrupada['IDHM Renda'], label='IDHM Renda')

  plt.title(f'IDHM e seus subtipos por estado ({regiao})')
  plt.legend(loc='lower left')
  plt.xticks(rotation = 90)
  plt.show()

# %%
scatter_estado_regiao('Norte')

# %%
scatter_estado_regiao('Nordeste')

# %%
scatter_estado_regiao('Sudeste')

# %%
scatter_estado_regiao('Sul')

# %%
scatter_estado_regiao('Centro-Oeste')

# %% [markdown]
# ## Abertura dos Indicadores

# %% [markdown]
# ### Educação

# %%
idhm_educacao = dados[['Nome da Unidade da Federação','IDHM Educação',
                       '% de 18 anos ou mais com fundamental completo', '% de 5 a 6 anos na escola',
                       '% de 11 a 13 anos nos anos finais do fundamental ou com fundamental completo',
                       '% de 15 a 17 anos com fundamental completo', '% de 18 a 20 anos com médio completo']]

# %%
idhm_educacao.head()
# Out:
#   Nome da Unidade da Federação  IDHM Educação  \
# 0                     Rondônia          0.526
# 1                     Rondônia          0.600
# 2                     Rondônia          0.559
# 3                     Rondônia          0.620
# 4                     Rondônia          0.602
#
#    % de 18 anos ou mais com fundamental completo  % de 5 a 6 anos na escola  \
# 0                                          36.80                      70.79
# 1                                          51.36                      77.46
# 2                                          35.65                      85.31
# 3                                          48.84                      85.61
# 4                                          42.98                      84.97
#
#    % de 11 a 13 anos nos anos finais do fundamental ou com fundamental completo  \
# 0                                              85.65
# 1                                              84.18
# ...

# %%
idhm_educacao_agrupado = idhm_educacao.groupby('Nome da Unidade da Federação').mean().sort_values(by='IDHM Educação',
    ascending=False)
idhm_educacao_agrupado.head()
# Out:
#                               IDHM Educação  \
# Nome da Unidade da Federação
# Distrito Federal                   0.742000
# São Paulo                          0.676336
# Santa Catarina                     0.636522
# Rio de Janeiro                     0.620902
# Paraná                             0.611045
#
#                               % de 18 anos ou mais com fundamental completo  \
# Nome da Unidade da Federação
# Distrito Federal                                                  72.320000
# São Paulo                                                         51.238000
# Santa Catarina                                                    45.321775
# Rio de Janeiro                                                    52.942500
# Paraná                                                            43.195388
#
#                               % de 5 a 6 anos na escola  \
# Nome da Unidade da Federação
# Distrito Federal                              92.460000
# ...

# %%
plt.figure(figsize=(11, 6))

plt.scatter(idhm_educacao_agrupado.index, idhm_educacao_agrupado['IDHM Educação']*100, label='IDHM Educação * 100')
plt.scatter(idhm_educacao_agrupado.index, idhm_educacao_agrupado['% de 18 anos ou mais com fundamental completo'],
            label='% 18+ com fundamental')
plt.scatter(idhm_educacao_agrupado.index, idhm_educacao_agrupado['% de 5 a 6 anos na escola'], label='% 5-6 na escola')
plt.scatter(idhm_educacao_agrupado.index,
              idhm_educacao_agrupado['% de 11 a 13 anos nos anos finais do fundamental ou com fundamental completo'],
              label='% 11-13 final fundamental')
plt.scatter(idhm_educacao_agrupado.index,
              idhm_educacao_agrupado['% de 15 a 17 anos com fundamental completo'], label='% 15-17 com fundamental')
plt.scatter(idhm_educacao_agrupado.index,
              idhm_educacao_agrupado['% de 18 a 20 anos com médio completo'], label='% 18-20 com médio')

plt.title('IDHM Educação e os índices que o compõe')
plt.legend(loc='lower left')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Longevidade

# %%
idhm_longevidade = dados[['Nome da Unidade da Federação','IDHM Longevidade','Esperança de vida ao nascer']]

# %%
idhm_longevidade.head()
# Out:
#   Nome da Unidade da Federação  IDHM Longevidade  Esperança de vida ao nascer
# 0                     Rondônia             0.763                        70.75
# 1                     Rondônia             0.806                        73.36
# 2                     Rondônia             0.757                        70.39
# 3                     Rondônia             0.821                        74.27
# 4                     Rondônia             0.799                        72.94

# %%
idhm_longevidade_agrupado = idhm_longevidade.groupby('Nome da Unidade da Federação').mean().sort_values(by='IDHM Longevidade',
    ascending=False)
idhm_longevidade_agrupado.head()
# Out:
#                               IDHM Longevidade  Esperança de vida ao nascer
# Nome da Unidade da Federação
# Distrito Federal                      0.873000                    77.350000
# Santa Catarina                        0.846966                    75.812116
# Rio Grande do Sul                     0.840429                    75.420948
# São Paulo                             0.835992                    75.153984
# Espírito Santo                        0.825744                    74.536026

# %%
idhm_longevidade_agrupado.plot(kind='bar', y='Esperança de vida ao nascer', figsize=(11, 6))
plt.title('Esperança de vida ao nascer por Estado')
plt.ylabel('Esperança de vida ao nascer')
plt.show()

# %% [markdown]
# ### Renda

# %%
idhm_renda = dados[['Nome da Unidade da Federação','IDHM Renda','Renda per capita']]

# %%
idhm_renda.head()
# Out:
#   Nome da Unidade da Federação  IDHM Renda  Renda per capita
# 0                     Rondônia       0.657            476.99
# 1                     Rondônia       0.716            689.95
# 2                     Rondônia       0.650            457.17
# 3                     Rondônia       0.727            738.06
# 4                     Rondônia       0.688            577.18

# %%
idhm_renda_agrupado = idhm_renda.groupby('Nome da Unidade da Federação').mean().sort_values(by='IDHM Renda',
    ascending=False)
idhm_renda_agrupado.head()
# Out:
#                               IDHM Renda  Renda per capita
# Nome da Unidade da Federação
# Distrito Federal                0.863000       1715.110000
# Santa Catarina                  0.728038        766.962150
# Rio Grande do Sul               0.722115        742.829153
# São Paulo                       0.716487        713.926155
# Rio de Janeiro                  0.704565        666.014674

# %%
idhm_renda_agrupado.plot(kind='bar', y='Renda per capita', figsize=(11, 6))
plt.title('Renda per capita por Estado')
plt.ylabel('Renda per capita')
plt.show()
